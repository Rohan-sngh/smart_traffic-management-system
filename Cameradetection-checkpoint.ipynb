# %%
from PIL import Image
import cv2
import numpy as np
import requests

# %%
import cv2
import numpy as np
import random
import time

# Load pre-trained cascade classifiers for each type of vehicle
car_cascade = cv2.CascadeClassifier(r"C:\Users\91957\Downloads\cars.xml")
two_wheeler_cascade = cv2.CascadeClassifier(r"C:\Users\91957\Downloads\two_wheeler.xml")
bus_cascade = cv2.CascadeClassifier(r"C:\Users\91957\Downloads\Bus_front.xml")

# Function to detect vehicles in an image
def detect_vehicles(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # Detect cars
    cars = car_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    # Detect two-wheelers
    two_wheelers = two_wheeler_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    # Detect buses
    buses = bus_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    
    # Combine all detections into a single list
    all_vehicles = list(cars) + list(two_wheelers) + list(buses)
    
    return len(all_vehicles), all_vehicles

# Simulate traffic volume data based on the number of detected vehicles
def simulate_traffic(total_vehicles):
    # Adjust traffic volume based on the total number of detected vehicles
    # You can define your logic here to map the number of vehicles to traffic volume
    # For simplicity, we'll use a linear mapping
    traffic_volume = total_vehicles * 10  # Example: Each vehicle contributes 10 units of traffic volume
    return min(100, traffic_volume)  # Ensure traffic volume does not exceed 100

# Algorithm to adjust signal duration based on traffic volume
def adjust_signal_duration(traffic_volume):
    if traffic_volume < 30:
        return 10  # Low traffic, longer green signal
    elif 30 <= traffic_volume < 70:
        return 5   # Moderate traffic, medium green signal
    else:
        return 3   # High traffic, short green signal

# Simulate traffic light control
def control_traffic_light():
    cap = cv2.VideoCapture(0)  # Use the default camera (change to desired camera index if needed)
    
    while True:
        ret, frame = cap.read()  # Read a frame from the camera
        
        # Detect vehicles in the frame
        total_vehicles, vehicle_boxes = detect_vehicles(frame)
        
        # Simulate traffic volume based on the number of detected vehicles
        traffic_volume = simulate_traffic(total_vehicles)
        
        # Adjust signal duration based on traffic volume
        signal_duration = adjust_signal_duration(traffic_volume)
        
        # Print traffic information
        print(f"Total vehicles detected: {total_vehicles}")
        print(f"Traffic volume: {traffic_volume}, Signal duration: {signal_duration} seconds")
        
        # Draw bounding boxes around detected vehicles
        for (x, y, w, h) in vehicle_boxes:
            cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)

        # Display the frame with bounding boxes
        cv2.imshow('Detected Vehicles', frame)
        
        # Exit loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
        
        # Simulate a time interval for real-time processing
        time.sleep(5)  

    # Release the camera and close OpenCV windows
    cap.release()
    cv2.destroyAllWindows()

# Run the traffic light control simulation
if __name__ == "__main__":
    control_traffic_light()
# Out:
# Total vehicles detected: 1
# Traffic volume: 10, Signal duration: 10 seconds
# Total vehicles detected: 1
# Traffic volume: 10, Signal duration: 10 seconds
# Total vehicles detected: 0
# Traffic volume: 0, Signal duration: 10 seconds
# Total vehicles detected: 1
# Traffic volume: 10, Signal duration: 10 seconds
# Total vehicles detected: 1
# Traffic volume: 10, Signal duration: 10 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 83
#      81 # Run the traffic light control simulation
#      82 if __name__ == "__main__":
# ---> 83     control_traffic_light()
#
# Cell In[2], line 75, in control_traffic_light()
#      72         break
#      74     # Simulate a time interval for real-time processing
# ---> 75     time.sleep(5)
#      77 # Release the camera and close OpenCV windows
#      78 cap.release()
#
# KeyboardInterrupt:

# %%
import cv2
import numpy as np
import random
import time

# Load pre-trained cascade classifiers for each type of vehicle
car_cascade = cv2.CascadeClassifier(r"C:\Users\91957\Downloads\cars.xml")
two_wheeler_cascade = cv2.CascadeClassifier(r"C:\Users\91957\Downloads\two_wheeler.xml")
bus_cascade = cv2.CascadeClassifier(r"C:\Users\91957\Downloads\Bus_front.xml")

# Function to detect vehicles in an image
def detect_vehicles(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # Detect cars
    cars = car_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    # Detect two-wheelers
    two_wheelers = two_wheeler_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    # Detect buses
    buses = bus_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    
    # Combine all detections into a single list
    all_vehicles = list(cars) + list(two_wheelers) + list(buses)
    
    return len(all_vehicles), all_vehicles

# Simulate traffic volume data based on the number of detected vehicles
def simulate_traffic(total_vehicles):
    # Adjust traffic volume based on the total number of detected vehicles
    # You can define your logic here to map the number of vehicles to traffic volume
    # For simplicity, we'll use a linear mapping
    traffic_volume = total_vehicles * 10  # Example: Each vehicle contributes 10 units of traffic volume
    return min(100, traffic_volume)  # Ensure traffic volume does not exceed 100

# Algorithm to adjust signal duration based on traffic volume
def adjust_signal_duration(traffic_volume):
    if traffic_volume < 30:
        return 10  # Low traffic, longer green signal
    elif 30 <= traffic_volume < 70:
        return 5   # Moderate traffic, medium green signal
    else:
        return 3   # High traffic, short green signal

# Simulate traffic light control
def control_traffic_light():
    cap = cv2.VideoCapture(0)  # Use the default camera (change to desired camera index if needed)
    
    while True:
        ret, frame = cap.read()  # Read a frame from the camera
        
        # Detect vehicles in the frame
        total_vehicles, vehicle_boxes = detect_vehicles(frame)
        
        # Simulate traffic volume based on the number of detected vehicles
        traffic_volume = simulate_traffic(total_vehicles)
        
        # Adjust signal duration based on traffic volume
        signal_duration = adjust_signal_duration(traffic_volume)
        
        # Print traffic information
        print(f"Total vehicles detected: {total_vehicles}")
        print(f"Traffic volume: {traffic_volume}, Signal duration: {signal_duration} seconds")
        
        # Draw bounding boxes around detected vehicles
        for (x, y, w, h) in vehicle_boxes:
            cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)

        # Display the frame with bounding boxes and camera feed
        cv2.imshow('Detected Vehicles', frame)
        
        # Exit loop if 'q' is pressed
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
        
        # Simulate a time interval for real-time processing
        time.sleep(5)  

    # Release the camera and close OpenCV windows
    cap.release()
    cv2.destroyAllWindows()

# Run the traffic light control simulation
if __name__ == "__main__":
    control_traffic_light()
# Out:
# Total vehicles detected: 1
# Traffic volume: 10, Signal duration: 10 seconds
# Total vehicles detected: 1
# Traffic volume: 10, Signal duration: 10 seconds
# Total vehicles detected: 0
# Traffic volume: 0, Signal duration: 10 seconds
# Total vehicles detected: 8
# Traffic volume: 80, Signal duration: 3 seconds
# Total vehicles detected: 5
# Traffic volume: 50, Signal duration: 5 seconds
# Total vehicles detected: 1
# Traffic volume: 10, Signal duration: 10 seconds
# Total vehicles detected: 0
# Traffic volume: 0, Signal duration: 10 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 83
#      81 # Run the traffic light control simulation
#      82 if __name__ == "__main__":
# ---> 83     control_traffic_light()
#
# Cell In[9], line 75, in control_traffic_light()
#      72         break
#      74     # Simulate a time interval for real-time processing
# ---> 75     time.sleep(5)
#      77 # Release the camera and close OpenCV windows
#      78 cap.release()
#
# KeyboardInterrupt:

# %%
import cv2
import numpy as np
import random
import time

# Load pre-trained cascade classifiers for each type of vehicle
# Load pre-trained cascade classifiers for each type of vehicle
car_cascade = cv2.CascadeClassifier(r"C:\Users\91957\Downloads\cars.xml")
two_wheeler_cascade = cv2.CascadeClassifier(r"C:\Users\91957\Downloads\two_wheeler.xml")
bus_cascade = cv2.CascadeClassifier(r"C:\Users\91957\Downloads\Bus_front.xml")

# Function to detect vehicles in an image
def detect_vehicles(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # Detect cars
    cars = car_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    # Detect two-wheelers
    two_wheelers = two_wheeler_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    # Detect buses
    buses = bus_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    
    # Combine all detections into a single list
    all_vehicles = list(cars) + list(two_wheelers) + list(buses)
    
    return len(all_vehicles), all_vehicles

# Simulate traffic volume data based on the number of detected vehicles
def simulate_traffic(total_vehicles):
    # Adjust traffic volume based on the total number of detected vehicles
    # You can define your logic here to map the number of vehicles to traffic volume
    # For simplicity, we'll use a linear mapping
    traffic_volume = total_vehicles * 10  # Example: Each vehicle contributes 10 units of traffic volume
    return min(100, traffic_volume)  # Ensure traffic volume does not exceed 100

# Algorithm to adjust signal duration based on traffic volume
def adjust_signal_duration(traffic_volume):
    if traffic_volume < 30:
        return 10  # Low traffic, longer green signal
    elif 30 <= traffic_volume < 70:
        return 5   # Moderate traffic, medium green signal
    else:
        return 3   # High traffic, short green signal

# Simulate traffic light control
def control_traffic_light():
    cap = cv2.VideoCapture(0)  # Use the default camera (change to desired camera index if needed)
    
    while True:
        # Begin traffic light cycle
        # Capture frame from camera
        ret, frame = cap.read()
        
        # Detect vehicles in the frame
        total_vehicles, vehicle_boxes = detect_vehicles(frame)
        
        # Simulate traffic volume based on the number of detected vehicles
        traffic_volume = simulate_traffic(total_vehicles)
        
        # Adjust signal duration based on traffic volume
        signal_duration = adjust_signal_duration(traffic_volume)
        
        # Print traffic information
        print(f"Total vehicles detected: {total_vehicles}")
        print(f"Traffic volume: {traffic_volume}, Signal duration: {signal_duration} seconds")
        
        # Draw bounding boxes around detected vehicles
        for (x, y, w, h) in vehicle_boxes:
            cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)

        # Display the frame with bounding boxes
        cv2.imshow('Traffic Monitoring', frame)
        
        # Wait for the signal duration
        time.sleep(signal_duration)
        
        # End traffic light cycle

        # Exit loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # Release the camera and close OpenCV windows
    cap.release()
    cv2.destroyAllWindows()

# Run the traffic light control simulation
if __name__ == "__main__":
    control_traffic_light()
# Out:
# Total vehicles detected: 1
# Traffic volume: 10, Signal duration: 10 seconds
# Total vehicles detected: 1
# Traffic volume: 10, Signal duration: 10 seconds
# Total vehicles detected: 0
# Traffic volume: 0, Signal duration: 10 seconds
# Total vehicles detected: 1
# Traffic volume: 10, Signal duration: 10 seconds
# Total vehicles detected: 0
# Traffic volume: 0, Signal duration: 10 seconds
# Total vehicles detected: 1
# Traffic volume: 10, Signal duration: 10 seconds
# Total vehicles detected: 4
# Traffic volume: 40, Signal duration: 5 seconds
# Total vehicles detected: 6
# Traffic volume: 60, Signal duration: 5 seconds
# Total vehicles detected: 7
# Traffic volume: 70, Signal duration: 3 seconds
# Total vehicles detected: 5
# Traffic volume: 50, Signal duration: 5 seconds
# Total vehicles detected: 4
# Traffic volume: 40, Signal duration: 5 seconds
# Total vehicles detected: 7
# Traffic volume: 70, Signal duration: 3 seconds
# Total vehicles detected: 6
# Traffic volume: 60, Signal duration: 5 seconds
# Total vehicles detected: 4
# Traffic volume: 40, Signal duration: 5 seconds
# Total vehicles detected: 0
# Traffic volume: 0, Signal duration: 10 seconds
# Total vehicles detected: 0
# Traffic volume: 0, Signal duration: 10 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 88
#      86 # Run the traffic light control simulation
#      87 if __name__ == "__main__":
# ---> 88     control_traffic_light()
#
# Cell In[4], line 74, in control_traffic_light()
#      71 cv2.imshow('Traffic Monitoring', frame)
#      73 # Wait for the signal duration
# ---> 74 time.sleep(signal_duration)
#      76 # End traffic light cycle
#      77
#      78 # Exit loop if 'q' is pressed
#      79 if cv2.waitKey(1) & 0xFF == ord('q'):
#
# KeyboardInterrupt:

# %%
import cv2
import numpy as np
import random
import time

# Load pre-trained cascade classifiers for each type of vehicle
# Load pre-trained cascade classifiers for each type of vehicle
car_cascade = cv2.CascadeClassifier(r"C:\Users\91957\Downloads\cars.xml")
two_wheeler_cascade = cv2.CascadeClassifier(r"C:\Users\91957\Downloads\two_wheeler.xml")
bus_cascade = cv2.CascadeClassifier(r"C:\Users\91957\Downloads\Bus_front.xml")

# Function to detect vehicles in an image
def detect_vehicles(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # Detect cars
    cars = car_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    # Detect two-wheelers
    two_wheelers = two_wheeler_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    # Detect buses
    buses = bus_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    
    # Combine all detections into a single list
    all_vehicles = list(cars) + list(two_wheelers) + list(buses)
    
    return len(all_vehicles), all_vehicles

# Simulate traffic volume data based on the number of detected vehicles
def simulate_traffic(total_vehicles):
    # Adjust traffic volume based on the total number of detected vehicles
    # You can define your logic here to map the number of vehicles to traffic volume
    # For simplicity, we'll use a linear mapping
    traffic_volume = total_vehicles * 10  # Example: Each vehicle contributes 10 units of traffic volume
    return min(100, traffic_volume)  # Ensure traffic volume does not exceed 100

# Algorithm to adjust signal duration based on traffic volume
def adjust_signal_duration(traffic_volume):
    if traffic_volume < 30:
        return 3  # Low traffic, shorter green signal
    elif 30 <= traffic_volume < 70:
        return 5   # Moderate traffic, medium green signal
    else:
        return 10   # High traffic, longer green signal

# Simulate traffic light control
def control_traffic_light():
    cap = cv2.VideoCapture(0)  # Use the default camera (change to desired camera index if needed)
    
    while True:
        # Begin traffic light cycle
        # Capture frame from camera
        ret, frame = cap.read()
        
        # Detect vehicles in the frame
        total_vehicles, vehicle_boxes = detect_vehicles(frame)
        
        # Simulate traffic volume based on the number of detected vehicles
        traffic_volume = simulate_traffic(total_vehicles)
        
        # Adjust signal duration based on traffic volume
        signal_duration = adjust_signal_duration(traffic_volume)
        
        # Print traffic information
        print(f"Total vehicles detected: {total_vehicles}")
        print(f"Traffic volume: {traffic_volume}, Signal duration: {signal_duration} seconds")
        
        # Draw bounding boxes around detected vehicles
        for (x, y, w, h) in vehicle_boxes:
            cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)

        # Display the frame with bounding boxes
        cv2.imshow('Traffic Monitoring', frame)
        
        # Wait for the signal duration
        time.sleep(signal_duration)
        
        # End traffic light cycle

        # Exit loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # Release the camera and close OpenCV windows
    cap.release()
    cv2.destroyAllWindows()

# Run the traffic light control simulation
if __name__ == "__main__":
    control_traffic_light()
# Out:
# Total vehicles detected: 1
# Traffic volume: 10, Signal duration: 3 seconds
# Total vehicles detected: 1
# Traffic volume: 10, Signal duration: 3 seconds
# Total vehicles detected: 0
# Traffic volume: 0, Signal duration: 3 seconds
# Total vehicles detected: 0
# Traffic volume: 0, Signal duration: 3 seconds
# Total vehicles detected: 0
# Traffic volume: 0, Signal duration: 3 seconds
# Total vehicles detected: 0
# Traffic volume: 0, Signal duration: 3 seconds
# Total vehicles detected: 0
# Traffic volume: 0, Signal duration: 3 seconds
# Total vehicles detected: 0
# Traffic volume: 0, Signal duration: 3 seconds
# Total vehicles detected: 2
# Traffic volume: 20, Signal duration: 3 seconds
# Total vehicles detected: 3
# Traffic volume: 30, Signal duration: 5 seconds
# Total vehicles detected: 5
# Traffic volume: 50, Signal duration: 5 seconds
# Total vehicles detected: 8
# Traffic volume: 80, Signal duration: 10 seconds
# Total vehicles detected: 3
# Traffic volume: 30, Signal duration: 5 seconds
# Total vehicles detected: 3
# Traffic volume: 30, Signal duration: 5 seconds
# Total vehicles detected: 0
# Traffic volume: 0, Signal duration: 3 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 88
#      86 # Run the traffic light control simulation
#      87 if __name__ == "__main__":
# ---> 88     control_traffic_light()
#
# Cell In[1], line 74, in control_traffic_light()
#      71 cv2.imshow('Traffic Monitoring', frame)
#      73 # Wait for the signal duration
# ---> 74 time.sleep(signal_duration)
#      76 # End traffic light cycle
#      77
#      78 # Exit loop if 'q' is pressed
#      79 if cv2.waitKey(1) & 0xFF == ord('q'):
#
# KeyboardInterrupt:

# %%
import cv2
import numpy as np
import random
import time

# Load pre-trained cascade classifiers for each type of vehicle
car_cascade = cv2.CascadeClassifier(r"C:\Users\91957\Downloads\cars.xml")
two_wheeler_cascade = cv2.CascadeClassifier(r"C:\Users\91957\Downloads\two_wheeler.xml")
bus_cascade = cv2.CascadeClassifier(r"C:\Users\91957\Downloads\Bus_front.xml")

# Function to detect vehicles in an image
def detect_vehicles(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # Detect cars
    cars = car_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    # Detect two-wheelers
    two_wheelers = two_wheeler_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    # Detect buses
    buses = bus_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    
    # Combine all detections into a single list
    all_vehicles = list(cars) + list(two_wheelers) + list(buses)
    
    return len(all_vehicles), all_vehicles

# Simulate traffic volume data based on the number of detected vehicles
def simulate_traffic(total_vehicles):
    # Adjust traffic volume based on the total number of detected vehicles
    # You can define your logic here to map the number of vehicles to traffic volume
    # For simplicity, we'll use a linear mapping
    traffic_volume = total_vehicles * 10  # Example: Each vehicle contributes 10 units of traffic volume
    return min(100, traffic_volume)  # Ensure traffic volume does not exceed 100

# Algorithm to adjust signal duration based on traffic volume
def adjust_signal_duration(traffic_volume):
    if traffic_volume < 30:
        return 10  # Low traffic, longer green signal
    elif 30 <= traffic_volume < 70:
        return 5   # Moderate traffic, medium green signal
    else:
        return 3   # High traffic, short green signal

# Simulate traffic light control
def control_traffic_light():
    cap = cv2.VideoCapture(0)  # Use the default camera (change to desired camera index if needed)
    
    while True:
        # Begin traffic light cycle
        # Capture frame from camera
        ret, frame = cap.read()
        
        # Detect vehicles in the frame
        total_vehicles, vehicle_boxes = detect_vehicles(frame)
        
        # Simulate traffic volume based on the number of detected vehicles
        traffic_volume = simulate_traffic(total_vehicles)
        
        # Adjust signal duration based on traffic volume
        signal_duration = adjust_signal_duration(traffic_volume)
        
        # Draw bounding boxes around detected vehicles
        for (x, y, w, h) in vehicle_boxes:
            cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)
        
        # Display the number of vehicles detected
        cv2.putText(frame, f"Total Vehicles: {total_vehicles}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

        # Display the frame with bounding boxes and vehicle count
        cv2.imshow('Traffic Monitoring', frame)
        
        # Wait for the signal duration
        time.sleep(5)
        
        # End traffic light cycle

        # Exit loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # Release the camera and close OpenCV windows
    cap.release()
    cv2.destroyAllWindows()

# Run the traffic light control simulation
if __name__ == "__main__":
    control_traffic_light()

# %%
import cv2
import numpy as np
import random
import time
import threading

# Load pre-trained cascade classifiers for each type of vehicle
car_cascade = cv2.CascadeClassifier(r"C:\Users\91957\Downloads\cars.xml")
two_wheeler_cascade = cv2.CascadeClassifier(r"C:\Users\91957\Downloads\two_wheeler.xml")
bus_cascade = cv2.CascadeClassifier(r"C:\Users\91957\Downloads\Bus_front.xml")

# Define the delay between consecutive vehicle detections (in seconds)
detection_delay = 3

# Function to detect vehicles in an image
def detect_vehicles(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # Detect cars
    cars = car_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    # Detect two-wheelers
    two_wheelers = two_wheeler_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    # Detect buses
    buses = bus_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
    
    # Combine all detections into a single list
    all_vehicles = list(cars) + list(two_wheelers) + list(buses)
    
    return len(all_vehicles), all_vehicles

# Simulate traffic volume data based on the number of detected vehicles
def simulate_traffic(total_vehicles):
    # Adjust traffic volume based on the total number of detected vehicles
    # You can define your logic here to map the number of vehicles to traffic volume
    # For simplicity, we'll use a linear mapping
    traffic_volume = total_vehicles * 10  # Example: Each vehicle contributes 10 units of traffic volume
    return min(100, traffic_volume)  # Ensure traffic volume does not exceed 100

# Algorithm to adjust signal duration based on traffic volume
def adjust_signal_duration(traffic_volume):
    if traffic_volume < 30:
        return 10  # Low traffic, longer green signal
    elif 30 <= traffic_volume < 70:
        return 5   # Moderate traffic, medium green signal
    else:
        return 3   # High traffic, short green signal

# Function to process frames and display traffic information
def process_frames():
    cap = cv2.VideoCapture(0)  # Use the default camera (change to desired camera index if needed)
    
    while True:
        # Capture frame from camera
        ret, frame = cap.read()
        
        # Detect vehicles in the frame
        total_vehicles, vehicle_boxes = detect_vehicles(frame)
        
        # Simulate traffic volume based on the number of detected vehicles
        traffic_volume = simulate_traffic(total_vehicles)
        
        # Adjust signal duration based on traffic volume
        signal_duration = adjust_signal_duration(traffic_volume)
        
        # Draw bounding boxes around detected vehicles
        for (x, y, w, h) in vehicle_boxes:
            cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)
        
        # Display the number of vehicles detected
        cv2.putText(frame, f"Total Vehicles: {total_vehicles}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA)
        
        # Display the signal duration
        cv2.putText(frame, f"Signal Duration: {signal_duration} seconds", (10, 70), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA)

        # Display the frame with bounding boxes, vehicle count, and signal duration
        cv2.imshow('Traffic Monitoring', frame)
        
        # Introduce a delay between consecutive vehicle detections
        time.sleep(detection_delay)
        
        # Exit loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # Release the camera and close OpenCV windows
    cap.release()
    cv2.destroyAllWindows()

# Run the process_frames function in a separate thread
if __name__ == "__main__":
    thread = threading.Thread(target=process_frames)
    thread.start()
